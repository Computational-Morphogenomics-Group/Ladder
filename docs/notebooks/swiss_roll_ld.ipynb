# %% [markdown]
# # Synthetic Examples
#
# Synthetic examples comparing different architectures using the low-level API of Ladder.

# %% [markdown]
# ## Imports

# %%
import torch, pyro, os, re, sys, warnings
import torch.utils.data as utils
import numpy as np
import pandas as pd
from ladder.models import SCVI, SCANVI, Patches, _broadcast_inputs
from ladder.scripts import train_pyro, train_pyro_disjoint_param, get_device, get_reproduction_error

from sklearn.datasets import make_swiss_roll
import umap
import seaborn as sns
import matplotlib.pyplot as plt
import math
import anndata as ad
import scanpy as sc

# %matplotlib inline

np.random.seed(42)
torch.manual_seed(42)
pyro.util.set_rng_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#device="cpu"

reducer = umap.UMAP(metric="euclidean", random_state=42, n_neighbors=100, min_dist=0.1)
warnings.filterwarnings('ignore')


print(f"Device: {device}")
# Out:
# Device: cuda

# %%
# Helpers for basic plots
def _transform_labels(labels):
    return torch.hstack((labels[:,:2].argmax(-1).view(-1,1), labels[:,2:].argmax(-1).view(-1,1)))

def get_labels(labels):
    labs = _transform_labels(labels)
    df = pd.DataFrame(labs)
    df["comb"] = df.apply(lambda x : str(x[0]) + "," + str(x[1]), axis = 1)
    return torch.tensor(pd.get_dummies(df["comb"]).astype(int).to_numpy())


#################### DATASET PARAMS #########################################################################################
n=2000  # Number of points in each attribute combination
batch_size=64 # Loader batch size
z_dim, w_dim=10, 10  # Latent dims of attributes and half dim of outputs
z_mean, z_std=0, 1  # Common latent parameters (gaussian)
a_10_mean, a_10_std, a_11_mean, a_11_std=0, 1, -1.15, 1  # Attribute 1 parameters: a10 --> Attribute 1 Off //  a11 --> Attribute 1 On // Parameters for respective gaussians
a_20_mean, a_20_std, a_21_mean, a_21_std=0, 1, 1.15, 1  # Attribute 2 parameters: a20 --> Attribute 2 Off // a21 --> Attribute 2 On // Parameters for respective gaussians
##################################################################################################################################

# Generate dataset
## Common
z_s = torch.normal(z_mean, z_std, size=(n*4, z_dim))


## Specific
w_0_0 = torch.concat((torch.normal(a_10_mean, a_10_std, size=(n, w_dim)), torch.normal(a_20_mean, a_20_std, size=(n, w_dim))), dim=-1)
w_0_1 = torch.concat((torch.normal(a_10_mean, a_10_std, size=(n, w_dim)), torch.normal(a_21_mean, a_21_std, size=(n, w_dim))), dim=-1)
w_1_0 = torch.concat((torch.normal(a_11_mean, a_11_std, size=(n, w_dim)), torch.normal(a_20_mean, a_20_std, size=(n, w_dim))), dim=-1)
w_1_1 = torch.concat((torch.normal(a_11_mean, a_11_std, size=(n, w_dim)), torch.normal(a_21_mean, a_21_std, size=(n, w_dim))), dim=-1)

## Combine Ws
w_s = torch.concat((w_0_0, w_0_1, w_1_0, w_1_1))

## Combine into full latents
data = torch.concat((z_s, w_s), dim=-1)

## Shift for non-negativity
data = data - data.min() + 1e-6

## Label Setup
labels = torch.concat((torch.tensor([1,0,1,0]).repeat((n,1)), torch.tensor([1,0,0,1]).repeat((n,1)), torch.tensor([0,1,1,0]).repeat((n,1)), torch.tensor([0,1,0,1]).repeat((n,1))))
labels_one_hot = torch.concat((torch.tensor([1,0,0,0]).repeat((n,1)), torch.tensor([0,1,0,0]).repeat((n,1)), torch.tensor([0,0,1,0]).repeat((n,1)), torch.tensor([0,0,0,1]).repeat((n,1))))


# Datasets & Loaders Setup
dataset = utils.TensorDataset(data.double(), labels.double(), labels.double())
dataset_one_hot = utils.TensorDataset(data.double(), labels_one_hot.double(), labels.double())
train_set, test_set = utils.random_split(dataset, [0.8, 0.2])
train_set_oh, test_set_oh = utils.random_split(dataset_one_hot, [0.8, 0.2])
train_loader, test_loader = utils.DataLoader(train_set, num_workers=4, batch_size=batch_size, shuffle=True), utils.DataLoader(test_set, num_workers=4, batch_size=batch_size, shuffle=False)
train_loader_oh, test_loader_oh = utils.DataLoader(train_set_oh, num_workers=4, batch_size=batch_size, shuffle=True), utils.DataLoader(test_set_oh, num_workers=4, batch_size=batch_size, shuffle=False)

run = 'gaussians'

# %% [markdown]
# ## Toy Dataset - Swiss Roll
#
# Recreation of the swiss roll example from the original CSVAE paper.

# %%
#################### DATASET PARAMS #########################################################################################
n=10000  # Number of points for the roll
batch_size=64 # Loader batch size
##################################################################################################################################


xs, _ = make_swiss_roll(n)
xs = torch.DoubleTensor(xs)
ys = torch.nn.functional.one_hot((xs[:, 1] < 10 ).type(torch.long)).double()
xs -= np.array([xs[:,0].min() -5, -5, xs[:,2].min() -5])
dataset = utils.TensorDataset(xs, ys, ys) # Duplicate ys, needed for workflow
train_set, test_set = dataset, utils.TensorDataset(*dataset[:batch_size]) # No test set  
train_loader, test_loader = torch.utils.data.DataLoader(train_set, shuffle=True, batch_size=batch_size), torch.utils.data.DataLoader(test_set, shuffle=False, batch_size=batch_size) # Test is dummy

run = 'roll'

# %% [markdown]
# ## Dataset Visualization
#
# Visually understanding the dataset generated in the previous step.

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')
scatter = ax.scatter(dataset[:][0][:,0], dataset[:][0][:,1], dataset[:][0][:,2], c=ys.argmax(-1), cmap="Set2")

elems = list(scatter.legend_elements())
legend = ax.legend(*elems,
                   loc="lower left", 
                   title="Classes",
                   title_fontsize=20,
                   fontsize=18,
                    markerscale=3)

ax.add_artist(legend)
ax.grid(False)

ax.set_xlabel('X', weight='bold', labelpad=30, fontsize=18)
ax.set_ylabel('Y', weight='bold', labelpad=30, fontsize=18)
ax.set_zlabel('Z', weight='bold', labelpad=7, fontsize=18)

#fig.savefig("swiss_roll.png", dpi=300, bbox_inches="tight")
        

plt.show()

# %% [markdown]
# ## Model

# %%
# Dry run
l_mean, l_scale = train_set[:][0].sum(-1).log().mean(), train_set[:][0].sum(-1).log().var()  #Ignored but needed for params
len_attrs = [2]

pyro.clear_param_store()

patches = Patches(
    num_genes=train_set[0][0].shape[0],
    num_labels=sum(len_attrs),
    l_loc=l_mean,
    l_scale=l_scale,
    len_attrs=len_attrs, betas = [1],
    scale_factor=1.0 / (batch_size * train_set[0][0].shape[0]), 
    batch_correction=False,
    reconstruction='Normal_LD',
    latent_dim=2,
    w_dim=1,
    num_layers=4,
    recon_weight=20,
    w_kl=1,
    z_kl=0.2,
    ).double()

patches, train_loss, test_loss, param_nonc_names, param_c_names =\
train_pyro_disjoint_param(patches, 
                          train_loader=train_loader, 
                          test_loader=test_loader, 
                          verbose=True, 
                          num_epochs=5,
                          convergence_window=10000,
                          optim_args={
                            "optim_args": {"lr": 1e-3, "eps": 1e-2, "betas": (0.9, 0.999)},   # Since we normalize by the 
                            "gamma": 0.14,
                            "milestones": [],
                          },)
# Out:
# Using device: cuda
#
# Epoch : 0 || Train Loss: 1933.27163 // 0.70176 || Test Loss: 465.19586 // 0.65162 || Warmup : False
# Epoch : 1 || Train Loss: 319.62296 // 0.69569 || Test Loss: 223.91339 // 0.69208 || Warmup : False
# Epoch : 2 || Train Loss: 183.70411 // 0.69372 || Test Loss: 149.99377 // 0.6829 || Warmup : False
# Epoch : 3 || Train Loss: 130.27639 // 0.69419 || Test Loss: 114.71666 // 0.67496 || Warmup : False
# Epoch : 4 || Train Loss: 104.55742 // 0.69417 || Test Loss: 96.49505 // 0.72757 || Warmup : False

# %%
# Full run

l_mean, l_scale = train_set[:][0].sum(-1).log().mean(), train_set[:][0].sum(-1).log().var()  #Ignored but needed for params
len_attrs = [2]

pyro.clear_param_store()

patches = Patches(
    num_genes=train_set[0][0].shape[0],
    num_labels=sum(len_attrs),
    l_loc=l_mean,
    l_scale=l_scale,
    len_attrs=len_attrs, betas = [1],
    scale_factor=1.0 / (batch_size * train_set[0][0].shape[0]), 
    batch_correction=False,
    reconstruction='Normal_LD',
    latent_dim=2,
    w_dim=1,
    num_layers=4,
    recon_weight=20,
    w_kl=1,
    z_kl=0.2,
    ).double()

patches, train_loss, test_loss, param_nonc_names, param_c_names =\
train_pyro_disjoint_param(patches, 
                          train_loader=train_loader, 
                          test_loader=test_loader, 
                          verbose=True, 
                          num_epochs=300,
                          convergence_window=10000,
                          optim_args={
                            "optim_args": {"lr": 1e-3, "eps": 1e-2, "betas": (0.9, 0.999)},   # Since we normalize by the 
                            "gamma": 0.14,
                            "milestones": [],
                          },)
# Out:
# Using device: cuda
#
# Epoch : 0 || Train Loss: 3658.51049 // 0.70782 || Test Loss: 872.60175 // 0.68797 || Warmup : False
# Epoch : 1 || Train Loss: 497.65174 // 0.69628 || Test Loss: 305.7522 // 0.69459 || Warmup : False
# Epoch : 2 || Train Loss: 231.54419 // 0.69523 || Test Loss: 179.4199 // 0.68704 || Warmup : False
# Epoch : 3 || Train Loss: 152.355 // 0.69359 || Test Loss: 129.618 // 0.69565 || Warmup : False
# Epoch : 4 || Train Loss: 115.82631 // 0.69338 || Test Loss: 109.26338 // 0.6811 || Warmup : False
# Epoch : 5 || Train Loss: 97.29397 // 0.69188 || Test Loss: 91.22931 // 0.67907 || Warmup : False
# Epoch : 6 || Train Loss: 87.20429 // 0.6934 || Test Loss: 82.45209 // 0.70167 || Warmup : False
# Epoch : 7 || Train Loss: 80.99474 // 0.6933 || Test Loss: 78.62734 // 0.69175 || Warmup : False
# Epoch : 8 || Train Loss: 77.04528 // 0.69317 || Test Loss: 74.62241 // 0.7101 || Warmup : False
# Epoch : 9 || Train Loss: 74.50398 // 0.6924 || Test Loss: 73.0076 // 0.68866 || Warmup : False
# Epoch : 10 || Train Loss: 72.67047 // 0.69418 || Test Loss: 71.35173 // 0.7014 || Warmup : False
# Epoch : 11 || Train Loss: 71.27822 // 0.69345 || Test Loss: 70.60253 // 0.70858 || Warmup : False
# Epoch : 12 || Train Loss: 70.31682 // 0.69279 || Test Loss: 69.35484 // 0.70613 || Warmup : False
# Epoch : 13 || Train Loss: 69.36765 // 0.69367 || Test Loss: 68.69544 // 0.68935 || Warmup : False
# Epoch : 14 || Train Loss: 68.69265 // 0.6937 || Test Loss: 67.68859 // 0.68929 || Warmup : False
# Epoch : 15 || Train Loss: 67.90666 // 0.69343 || Test Loss: 67.37876 // 0.70792 || Warmup : False
# Epoch : 16 || Train Loss: 67.20043 // 0.69267 || Test Loss: 66.4149 // 0.70229 || Warmup : False
# Epoch : 17 || Train Loss: 66.53637 // 0.69428 || Test Loss: 65.52978 // 0.68457 || Warmup : False
# Epoch : 18 || Train Loss: 65.85276 // 0.69379 || Test Loss: 65.14296 // 0.68068 || Warmup : False
# Epoch : 19 || Train Loss: 65.15159 // 0.69281 || Test Loss: 64.10641 // 0.68774 || Warmup : False
# Epoch : 20 || Train Loss: 64.40012 // 0.69262 || Test Loss: 63.47927 // 0.69002 || Warmup : False
# Epoch : 21 || Train Loss: 63.70228 // 0.69398 || Test Loss: 63.1813 // 0.68894 || Warmup : False
# Epoch : 22 || Train Loss: 62.83579 // 0.69265 || Test Loss: 62.14222 // 0.68079 || Warmup : False
# Epoch : 23 || Train Loss: 62.07693 // 0.69418 || Test Loss: 61.16593 // 0.68118 || Warmup : False
# Epoch : 24 || Train Loss: 61.0175 // 0.6934 || Test Loss: 60.07426 // 0.70281 || Warmup : False
# Epoch : 25 || Train Loss: 60.15311 // 0.69399 || Test Loss: 59.13824 // 0.69707 || Warmup : False
# Epoch : 26 || Train Loss: 59.33109 // 0.69372 || Test Loss: 58.61653 // 0.68239 || Warmup : False
# Epoch : 27 || Train Loss: 58.29443 // 0.69405 || Test Loss: 57.76753 // 0.69431 || Warmup : False
# Epoch : 28 || Train Loss: 57.41087 // 0.69376 || Test Loss: 57.20952 // 0.69713 || Warmup : False
# Epoch : 29 || Train Loss: 56.53908 // 0.69414 || Test Loss: 55.57952 // 0.73285 || Warmup : False
# Epoch : 30 || Train Loss: 55.68601 // 0.69513 || Test Loss: 54.72092 // 0.67388 || Warmup : False
# Epoch : 31 || Train Loss: 54.865 // 0.69534 || Test Loss: 53.26806 // 0.71134 || Warmup : False
# Epoch : 32 || Train Loss: 54.04224 // 0.69516 || Test Loss: 52.39415 // 0.70249 || Warmup : False
# Epoch : 33 || Train Loss: 53.13462 // 0.69598 || Test Loss: 50.73489 // 0.69445 || Warmup : False
# Epoch : 34 || Train Loss: 52.21367 // 0.69496 || Test Loss: 50.91575 // 0.68773 || Warmup : False
# Epoch : 35 || Train Loss: 51.55433 // 0.6953 || Test Loss: 49.96693 // 0.66069 || Warmup : False
# Epoch : 36 || Train Loss: 50.47516 // 0.69759 || Test Loss: 48.17548 // 0.69941 || Warmup : False
# Epoch : 37 || Train Loss: 49.69332 // 0.69558 || Test Loss: 48.35186 // 0.69835 || Warmup : False
# Epoch : 38 || Train Loss: 48.65649 // 0.69476 || Test Loss: 46.46057 // 0.68559 || Warmup : False
# Epoch : 39 || Train Loss: 47.45775 // 0.69442 || Test Loss: 43.48262 // 0.68084 || Warmup : False
# Epoch : 40 || Train Loss: 45.52134 // 0.69301 || Test Loss: 43.44991 // 0.68825 || Warmup : False
# Epoch : 41 || Train Loss: 44.32549 // 0.69387 || Test Loss: 41.30373 // 0.68346 || Warmup : False
# Epoch : 42 || Train Loss: 43.17043 // 0.69274 || Test Loss: 40.32265 // 0.69191 || Warmup : False
# Epoch : 43 || Train Loss: 41.97606 // 0.69337 || Test Loss: 40.74716 // 0.68188 || Warmup : False
# Epoch : 44 || Train Loss: 40.80831 // 0.69323 || Test Loss: 38.12729 // 0.69036 || Warmup : False
# Epoch : 45 || Train Loss: 39.78219 // 0.69244 || Test Loss: 35.87278 // 0.68131 || Warmup : False
# Epoch : 46 || Train Loss: 39.0677 // 0.69319 || Test Loss: 37.21199 // 0.67545 || Warmup : False
# Epoch : 47 || Train Loss: 38.12386 // 0.69332 || Test Loss: 33.96343 // 0.69235 || Warmup : False
# Epoch : 48 || Train Loss: 36.90184 // 0.69344 || Test Loss: 34.06198 // 0.68573 || Warmup : False
# Epoch : 49 || Train Loss: 36.68263 // 0.69425 || Test Loss: 33.40335 // 0.6829 || Warmup : False
# Epoch : 50 || Train Loss: 35.98076 // 0.69371 || Test Loss: 32.10778 // 0.68285 || Warmup : False
# Epoch : 51 || Train Loss: 35.09506 // 0.69298 || Test Loss: 33.50989 // 0.68567 || Warmup : False
# Epoch : 52 || Train Loss: 35.34759 // 0.69326 || Test Loss: 29.98233 // 0.68074 || Warmup : False
# Epoch : 53 || Train Loss: 33.6445 // 0.69286 || Test Loss: 30.00001 // 0.69472 || Warmup : False
# Epoch : 54 || Train Loss: 33.58162 // 0.69303 || Test Loss: 28.88313 // 0.69567 || Warmup : False
# Epoch : 55 || Train Loss: 32.65925 // 0.69287 || Test Loss: 29.90327 // 0.69002 || Warmup : False
# Epoch : 56 || Train Loss: 31.5687 // 0.69296 || Test Loss: 28.42689 // 0.689 || Warmup : False
# Epoch : 57 || Train Loss: 31.17506 // 0.69345 || Test Loss: 28.05365 // 0.68156 || Warmup : False
# Epoch : 58 || Train Loss: 31.61054 // 0.69296 || Test Loss: 28.00466 // 0.6817 || Warmup : False
# Epoch : 59 || Train Loss: 30.39759 // 0.69261 || Test Loss: 27.63782 // 0.6897 || Warmup : False
# Epoch : 60 || Train Loss: 30.61427 // 0.69319 || Test Loss: 24.73853 // 0.69785 || Warmup : False
# Epoch : 61 || Train Loss: 29.39435 // 0.69322 || Test Loss: 25.37958 // 0.68403 || Warmup : False
# Epoch : 62 || Train Loss: 29.23794 // 0.69253 || Test Loss: 27.44062 // 0.69292 || Warmup : False
# Epoch : 63 || Train Loss: 29.25491 // 0.69284 || Test Loss: 28.7011 // 0.70126 || Warmup : False
# Epoch : 64 || Train Loss: 28.40951 // 0.69308 || Test Loss: 22.95856 // 0.69419 || Warmup : False
# Epoch : 65 || Train Loss: 28.69285 // 0.69257 || Test Loss: 25.75109 // 0.69605 || Warmup : False
# Epoch : 66 || Train Loss: 28.16747 // 0.69351 || Test Loss: 22.56925 // 0.6941 || Warmup : False
# Epoch : 67 || Train Loss: 27.04636 // 0.69249 || Test Loss: 21.93733 // 0.6953 || Warmup : False
# Epoch : 68 || Train Loss: 26.96882 // 0.69348 || Test Loss: 22.85966 // 0.68473 || Warmup : False
# Epoch : 69 || Train Loss: 26.33865 // 0.69269 || Test Loss: 22.80045 // 0.69378 || Warmup : False
# Epoch : 70 || Train Loss: 27.06104 // 0.69295 || Test Loss: 22.98001 // 0.69003 || Warmup : False
# Epoch : 71 || Train Loss: 26.17654 // 0.6925 || Test Loss: 23.88761 // 0.69998 || Warmup : False
# Epoch : 72 || Train Loss: 25.53592 // 0.69362 || Test Loss: 22.36787 // 0.69831 || Warmup : False
# Epoch : 73 || Train Loss: 24.61417 // 0.69274 || Test Loss: 21.2848 // 0.69012 || Warmup : False
# Epoch : 74 || Train Loss: 24.95847 // 0.69287 || Test Loss: 25.63024 // 0.67701 || Warmup : False
# Epoch : 75 || Train Loss: 25.18377 // 0.69238 || Test Loss: 21.5878 // 0.69147 || Warmup : False
# Epoch : 76 || Train Loss: 24.7866 // 0.69359 || Test Loss: 23.84143 // 0.69856 || Warmup : False
# Epoch : 77 || Train Loss: 23.55648 // 0.69267 || Test Loss: 22.64558 // 0.68724 || Warmup : False
# Epoch : 78 || Train Loss: 23.41854 // 0.69197 || Test Loss: 21.19293 // 0.69501 || Warmup : False
# Epoch : 79 || Train Loss: 22.57562 // 0.69281 || Test Loss: 23.82378 // 0.68082 || Warmup : False
# Epoch : 80 || Train Loss: 23.0141 // 0.6924 || Test Loss: 21.39426 // 0.69313 || Warmup : False
# Epoch : 81 || Train Loss: 22.8725 // 0.69203 || Test Loss: 21.53392 // 0.69447 || Warmup : False
# Epoch : 82 || Train Loss: 22.22177 // 0.69327 || Test Loss: 22.38277 // 0.69844 || Warmup : False
# Epoch : 83 || Train Loss: 21.57303 // 0.69253 || Test Loss: 21.89166 // 0.70157 || Warmup : False
# Epoch : 84 || Train Loss: 21.60315 // 0.69237 || Test Loss: 21.12838 // 0.69171 || Warmup : False
# Epoch : 85 || Train Loss: 22.06362 // 0.69157 || Test Loss: 19.55123 // 0.692 || Warmup : False
# Epoch : 86 || Train Loss: 21.81122 // 0.69212 || Test Loss: 18.44499 // 0.67887 || Warmup : False
# Epoch : 87 || Train Loss: 21.11392 // 0.69202 || Test Loss: 20.26565 // 0.69548 || Warmup : False
# Epoch : 88 || Train Loss: 20.47552 // 0.693 || Test Loss: 25.43186 // 0.68745 || Warmup : False
# Epoch : 89 || Train Loss: 20.21521 // 0.69257 || Test Loss: 19.18145 // 0.69274 || Warmup : False
# Epoch : 90 || Train Loss: 20.01874 // 0.69258 || Test Loss: 19.97053 // 0.69437 || Warmup : False
# Epoch : 91 || Train Loss: 20.37048 // 0.69303 || Test Loss: 19.59389 // 0.70059 || Warmup : False
# Epoch : 92 || Train Loss: 19.90025 // 0.69249 || Test Loss: 22.22299 // 0.68609 || Warmup : False
# Epoch : 93 || Train Loss: 19.5645 // 0.69248 || Test Loss: 17.21102 // 0.69276 || Warmup : False
# Epoch : 94 || Train Loss: 19.43726 // 0.69172 || Test Loss: 19.16999 // 0.69959 || Warmup : False
# Epoch : 95 || Train Loss: 18.84313 // 0.69291 || Test Loss: 16.60394 // 0.68129 || Warmup : False
# Epoch : 96 || Train Loss: 19.39072 // 0.6928 || Test Loss: 17.80327 // 0.68469 || Warmup : False
# Epoch : 97 || Train Loss: 18.88101 // 0.69278 || Test Loss: 22.27025 // 0.68972 || Warmup : False
# Epoch : 98 || Train Loss: 18.32941 // 0.69245 || Test Loss: 21.29792 // 0.68501 || Warmup : False
# Epoch : 99 || Train Loss: 18.75637 // 0.69244 || Test Loss: 18.17771 // 0.69265 || Warmup : False
# Epoch : 100 || Train Loss: 19.54846 // 0.69223 || Test Loss: 17.01857 // 0.69565 || Warmup : False
# Epoch : 101 || Train Loss: 18.18751 // 0.69242 || Test Loss: 15.20181 // 0.6891 || Warmup : False
# Epoch : 102 || Train Loss: 18.00755 // 0.69193 || Test Loss: 18.03087 // 0.69207 || Warmup : False
# Epoch : 103 || Train Loss: 17.9663 // 0.69213 || Test Loss: 17.24748 // 0.69508 || Warmup : False
# Epoch : 104 || Train Loss: 17.73261 // 0.69358 || Test Loss: 16.54664 // 0.68649 || Warmup : False
# Epoch : 105 || Train Loss: 16.7035 // 0.69219 || Test Loss: 19.11355 // 0.68599 || Warmup : False
# Epoch : 106 || Train Loss: 16.94439 // 0.69238 || Test Loss: 17.05486 // 0.69613 || Warmup : False
# Epoch : 107 || Train Loss: 17.08161 // 0.69198 || Test Loss: 19.47424 // 0.6981 || Warmup : False
# Epoch : 108 || Train Loss: 16.19335 // 0.69219 || Test Loss: 19.0821 // 0.68687 || Warmup : False
# Epoch : 109 || Train Loss: 16.59744 // 0.69291 || Test Loss: 16.60699 // 0.69681 || Warmup : False
# Epoch : 110 || Train Loss: 16.5411 // 0.69228 || Test Loss: 16.39093 // 0.68571 || Warmup : False
# Epoch : 111 || Train Loss: 15.95873 // 0.69168 || Test Loss: 14.98211 // 0.69449 || Warmup : False
# Epoch : 112 || Train Loss: 15.72365 // 0.69217 || Test Loss: 18.41561 // 0.68937 || Warmup : False
# Epoch : 113 || Train Loss: 16.14096 // 0.69257 || Test Loss: 29.89407 // 0.69406 || Warmup : False
# Epoch : 114 || Train Loss: 15.65099 // 0.69272 || Test Loss: 15.74475 // 0.68145 || Warmup : False
# Epoch : 115 || Train Loss: 15.39469 // 0.69193 || Test Loss: 25.63832 // 0.6982 || Warmup : False
# Epoch : 116 || Train Loss: 16.02143 // 0.69228 || Test Loss: 19.33308 // 0.687 || Warmup : False
# Epoch : 117 || Train Loss: 15.61777 // 0.69243 || Test Loss: 17.14655 // 0.69014 || Warmup : False
# Epoch : 118 || Train Loss: 14.4673 // 0.69238 || Test Loss: 26.52389 // 0.69352 || Warmup : False
# Epoch : 119 || Train Loss: 14.64398 // 0.69233 || Test Loss: 19.07715 // 0.69259 || Warmup : False
# Epoch : 120 || Train Loss: 15.05602 // 0.69204 || Test Loss: 14.152 // 0.68934 || Warmup : False
# Epoch : 121 || Train Loss: 15.41854 // 0.69226 || Test Loss: 21.61558 // 0.69113 || Warmup : False
# Epoch : 122 || Train Loss: 14.45602 // 0.69209 || Test Loss: 14.53273 // 0.68876 || Warmup : False
# Epoch : 123 || Train Loss: 14.27703 // 0.6927 || Test Loss: 16.24226 // 0.69096 || Warmup : False
# Epoch : 124 || Train Loss: 15.57098 // 0.69217 || Test Loss: 18.49307 // 0.69491 || Warmup : False
# Epoch : 125 || Train Loss: 14.84288 // 0.69268 || Test Loss: 18.50257 // 0.69432 || Warmup : False
# Epoch : 126 || Train Loss: 14.449 // 0.69261 || Test Loss: 17.31893 // 0.69254 || Warmup : False
# Epoch : 127 || Train Loss: 12.51799 // 0.69172 || Test Loss: 23.40675 // 0.68744 || Warmup : False
# Epoch : 128 || Train Loss: 14.05136 // 0.69192 || Test Loss: 16.64985 // 0.70145 || Warmup : False
# Epoch : 129 || Train Loss: 14.31886 // 0.69206 || Test Loss: 14.82273 // 0.69165 || Warmup : False
# Epoch : 130 || Train Loss: 14.40964 // 0.69168 || Test Loss: 16.49169 // 0.69029 || Warmup : False
# Epoch : 131 || Train Loss: 14.65663 // 0.69256 || Test Loss: 23.45155 // 0.6891 || Warmup : False
# Epoch : 132 || Train Loss: 14.16964 // 0.69281 || Test Loss: 13.17884 // 0.69093 || Warmup : False
# Epoch : 133 || Train Loss: 13.13332 // 0.69239 || Test Loss: 15.29103 // 0.68132 || Warmup : False
# Epoch : 134 || Train Loss: 13.25542 // 0.69247 || Test Loss: 13.85933 // 0.69571 || Warmup : False
# Epoch : 135 || Train Loss: 13.48389 // 0.69277 || Test Loss: 25.82204 // 0.6908 || Warmup : False
# Epoch : 136 || Train Loss: 12.79434 // 0.69148 || Test Loss: 16.32978 // 0.6897 || Warmup : False
# Epoch : 137 || Train Loss: 12.98509 // 0.69171 || Test Loss: 13.9994 // 0.68977 || Warmup : False
# Epoch : 138 || Train Loss: 12.74391 // 0.69271 || Test Loss: 15.58094 // 0.68723 || Warmup : False
# Epoch : 139 || Train Loss: 12.31753 // 0.69216 || Test Loss: 21.67377 // 0.69035 || Warmup : False
# Epoch : 140 || Train Loss: 11.59298 // 0.69196 || Test Loss: 18.56835 // 0.69362 || Warmup : False
# Epoch : 141 || Train Loss: 15.73215 // 0.69194 || Test Loss: 33.7697 // 0.69106 || Warmup : False
# Epoch : 142 || Train Loss: 13.11865 // 0.6919 || Test Loss: 12.08548 // 0.68895 || Warmup : False
# Epoch : 143 || Train Loss: 12.56707 // 0.69164 || Test Loss: 23.34819 // 0.68517 || Warmup : False
# Epoch : 144 || Train Loss: 12.48417 // 0.69201 || Test Loss: 15.0734 // 0.69469 || Warmup : False
# Epoch : 145 || Train Loss: 12.32029 // 0.69262 || Test Loss: 13.25731 // 0.68829 || Warmup : False
# Epoch : 146 || Train Loss: 14.28227 // 0.69272 || Test Loss: 10.93031 // 0.69064 || Warmup : False
# Epoch : 147 || Train Loss: 13.44089 // 0.69165 || Test Loss: 16.73461 // 0.69205 || Warmup : False
# Epoch : 148 || Train Loss: 13.20474 // 0.69187 || Test Loss: 17.55479 // 0.68878 || Warmup : False
# Epoch : 149 || Train Loss: 11.72385 // 0.69153 || Test Loss: 21.90016 // 0.6926 || Warmup : False
# Epoch : 150 || Train Loss: 12.5779 // 0.69229 || Test Loss: 15.32497 // 0.6903 || Warmup : False
# Epoch : 151 || Train Loss: 11.36336 // 0.69196 || Test Loss: 18.18195 // 0.68652 || Warmup : False
# Epoch : 152 || Train Loss: 11.40074 // 0.69243 || Test Loss: 18.2172 // 0.69298 || Warmup : False
# Epoch : 153 || Train Loss: 11.80056 // 0.69164 || Test Loss: 15.76772 // 0.68649 || Warmup : False
# Epoch : 154 || Train Loss: 10.91343 // 0.69095 || Test Loss: 11.61285 // 0.6877 || Warmup : False
# Epoch : 155 || Train Loss: 11.74399 // 0.6919 || Test Loss: 14.04387 // 0.69147 || Warmup : False
# Epoch : 156 || Train Loss: 9.95591 // 0.69207 || Test Loss: 16.25683 // 0.70252 || Warmup : False
# Epoch : 157 || Train Loss: 11.05612 // 0.69238 || Test Loss: 25.67135 // 0.69054 || Warmup : False
# Epoch : 158 || Train Loss: 11.30028 // 0.69114 || Test Loss: 14.91503 // 0.69884 || Warmup : False
# Epoch : 159 || Train Loss: 11.3151 // 0.69165 || Test Loss: 13.128 // 0.69257 || Warmup : False
# Epoch : 160 || Train Loss: 12.41748 // 0.69195 || Test Loss: 17.74498 // 0.69038 || Warmup : False
# Epoch : 161 || Train Loss: 11.71537 // 0.69215 || Test Loss: 23.75974 // 0.69537 || Warmup : False
# Epoch : 162 || Train Loss: 11.10753 // 0.69205 || Test Loss: 23.47224 // 0.694 || Warmup : False
# Epoch : 163 || Train Loss: 11.46566 // 0.69219 || Test Loss: 19.09179 // 0.6894 || Warmup : False
# Epoch : 164 || Train Loss: 10.85023 // 0.69169 || Test Loss: 22.84211 // 0.69238 || Warmup : False
# Epoch : 165 || Train Loss: 13.03231 // 0.69166 || Test Loss: 15.41815 // 0.6962 || Warmup : False
# Epoch : 166 || Train Loss: 9.34336 // 0.6919 || Test Loss: 12.54459 // 0.68418 || Warmup : False
# Epoch : 167 || Train Loss: 11.14858 // 0.69129 || Test Loss: 18.71751 // 0.6907 || Warmup : False
# Epoch : 168 || Train Loss: 11.44475 // 0.69206 || Test Loss: 23.76949 // 0.69211 || Warmup : False
# Epoch : 169 || Train Loss: 11.12093 // 0.69203 || Test Loss: 11.49566 // 0.68962 || Warmup : False
# Epoch : 170 || Train Loss: 9.81656 // 0.69184 || Test Loss: 20.41017 // 0.68845 || Warmup : False
# Epoch : 171 || Train Loss: 10.94987 // 0.69248 || Test Loss: 25.43572 // 0.69128 || Warmup : False
# Epoch : 172 || Train Loss: 9.71006 // 0.69202 || Test Loss: 14.8213 // 0.69589 || Warmup : False
# Epoch : 173 || Train Loss: 11.84078 // 0.69164 || Test Loss: 23.26488 // 0.69289 || Warmup : False
# Epoch : 174 || Train Loss: 9.83163 // 0.69183 || Test Loss: 18.94478 // 0.68872 || Warmup : False
# Epoch : 175 || Train Loss: 10.73348 // 0.69221 || Test Loss: 20.85992 // 0.68308 || Warmup : False
# Epoch : 176 || Train Loss: 9.79494 // 0.6919 || Test Loss: 28.36074 // 0.69023 || Warmup : False
# Epoch : 177 || Train Loss: 10.75594 // 0.69125 || Test Loss: 20.21809 // 0.69954 || Warmup : False
# Epoch : 178 || Train Loss: 10.69003 // 0.69208 || Test Loss: 14.28326 // 0.69068 || Warmup : False
# Epoch : 179 || Train Loss: 9.83783 // 0.69155 || Test Loss: 19.23221 // 0.68497 || Warmup : False
# Epoch : 180 || Train Loss: 9.93329 // 0.69242 || Test Loss: 11.13376 // 0.69402 || Warmup : False
# Epoch : 181 || Train Loss: 9.64169 // 0.69129 || Test Loss: 17.0302 // 0.69994 || Warmup : False
# Epoch : 182 || Train Loss: 9.59542 // 0.69232 || Test Loss: 13.5784 // 0.6893 || Warmup : False
# Epoch : 183 || Train Loss: 10.4355 // 0.69182 || Test Loss: 22.6913 // 0.68803 || Warmup : False
# Epoch : 184 || Train Loss: 9.37399 // 0.69172 || Test Loss: 11.16987 // 0.6951 || Warmup : False
# Epoch : 185 || Train Loss: 9.65929 // 0.69161 || Test Loss: 25.23629 // 0.68943 || Warmup : False
# Epoch : 186 || Train Loss: 9.54049 // 0.69253 || Test Loss: 10.28066 // 0.69443 || Warmup : False
# Epoch : 187 || Train Loss: 9.78944 // 0.69199 || Test Loss: 18.01968 // 0.69131 || Warmup : False
# Epoch : 188 || Train Loss: 8.73235 // 0.69177 || Test Loss: 22.45325 // 0.68759 || Warmup : False
# Epoch : 189 || Train Loss: 9.9894 // 0.69174 || Test Loss: 12.63987 // 0.69163 || Warmup : False
# Epoch : 190 || Train Loss: 9.45171 // 0.69092 || Test Loss: 23.41219 // 0.69207 || Warmup : False
# Epoch : 191 || Train Loss: 9.4329 // 0.69208 || Test Loss: 12.7479 // 0.68522 || Warmup : False
# Epoch : 192 || Train Loss: 10.38269 // 0.69164 || Test Loss: 17.7491 // 0.6924 || Warmup : False
# Epoch : 193 || Train Loss: 9.03944 // 0.69158 || Test Loss: 12.34951 // 0.69787 || Warmup : False
# Epoch : 194 || Train Loss: 9.22801 // 0.69223 || Test Loss: 18.72527 // 0.69257 || Warmup : False
# Epoch : 195 || Train Loss: 8.50036 // 0.69137 || Test Loss: 15.90704 // 0.6897 || Warmup : False
# Epoch : 196 || Train Loss: 8.63153 // 0.69146 || Test Loss: 22.0121 // 0.69044 || Warmup : False
# Epoch : 197 || Train Loss: 9.04469 // 0.69152 || Test Loss: 20.90416 // 0.68882 || Warmup : False
# Epoch : 198 || Train Loss: 9.7595 // 0.69135 || Test Loss: 12.19741 // 0.69277 || Warmup : False
# Epoch : 199 || Train Loss: 8.94418 // 0.69239 || Test Loss: 17.56319 // 0.68523 || Warmup : False
# Epoch : 200 || Train Loss: 8.9495 // 0.69181 || Test Loss: 21.37804 // 0.69312 || Warmup : False
# Epoch : 201 || Train Loss: 9.86223 // 0.69199 || Test Loss: 22.74931 // 0.69767 || Warmup : False
# Epoch : 202 || Train Loss: 8.59163 // 0.69199 || Test Loss: 17.00287 // 0.69211 || Warmup : False
# Epoch : 203 || Train Loss: 8.57149 // 0.69157 || Test Loss: 24.55618 // 0.6923 || Warmup : False
# Epoch : 204 || Train Loss: 8.29946 // 0.69184 || Test Loss: 17.83748 // 0.68583 || Warmup : False
# Epoch : 205 || Train Loss: 9.83462 // 0.69245 || Test Loss: 17.57035 // 0.69818 || Warmup : False
# Epoch : 206 || Train Loss: 8.56231 // 0.69216 || Test Loss: 18.69409 // 0.69586 || Warmup : False
# Epoch : 207 || Train Loss: 8.84902 // 0.69128 || Test Loss: 21.64661 // 0.68776 || Warmup : False
# Epoch : 208 || Train Loss: 8.53588 // 0.69137 || Test Loss: 16.30104 // 0.69448 || Warmup : False
# Epoch : 209 || Train Loss: 8.92127 // 0.69175 || Test Loss: 26.50089 // 0.68502 || Warmup : False
# Epoch : 210 || Train Loss: 8.88102 // 0.69192 || Test Loss: 20.37288 // 0.68412 || Warmup : False
# Epoch : 211 || Train Loss: 8.01733 // 0.6919 || Test Loss: 9.18867 // 0.68831 || Warmup : False
# Epoch : 212 || Train Loss: 7.72761 // 0.69166 || Test Loss: 20.30431 // 0.68915 || Warmup : False
# Epoch : 213 || Train Loss: 9.15114 // 0.69149 || Test Loss: 17.80547 // 0.68884 || Warmup : False
# Epoch : 214 || Train Loss: 7.99382 // 0.69187 || Test Loss: 13.52055 // 0.69108 || Warmup : False
# Epoch : 215 || Train Loss: 7.62462 // 0.692 || Test Loss: 16.94313 // 0.6881 || Warmup : False
# Epoch : 216 || Train Loss: 8.02107 // 0.6914 || Test Loss: 33.55486 // 0.69328 || Warmup : False
# Epoch : 217 || Train Loss: 7.0578 // 0.69194 || Test Loss: 19.21179 // 0.69091 || Warmup : False
# Epoch : 218 || Train Loss: 7.07711 // 0.69141 || Test Loss: 17.93679 // 0.69068 || Warmup : False
# Epoch : 219 || Train Loss: 7.22098 // 0.69161 || Test Loss: 17.15685 // 0.68466 || Warmup : False
# Epoch : 220 || Train Loss: 8.48104 // 0.69162 || Test Loss: 15.18957 // 0.69088 || Warmup : False
# Epoch : 221 || Train Loss: 7.19714 // 0.69197 || Test Loss: 20.71994 // 0.69147 || Warmup : False
# Epoch : 222 || Train Loss: 7.86046 // 0.69235 || Test Loss: 18.73072 // 0.69841 || Warmup : False
# Epoch : 223 || Train Loss: 7.51626 // 0.69172 || Test Loss: 12.35833 // 0.68472 || Warmup : False
# Epoch : 224 || Train Loss: 9.06947 // 0.6915 || Test Loss: 17.02937 // 0.68547 || Warmup : False
# Epoch : 225 || Train Loss: 7.94764 // 0.69182 || Test Loss: 24.09899 // 0.6926 || Warmup : False
# Epoch : 226 || Train Loss: 8.65969 // 0.69175 || Test Loss: 22.19276 // 0.6887 || Warmup : False
# Epoch : 227 || Train Loss: 6.06504 // 0.69154 || Test Loss: 23.39503 // 0.69131 || Warmup : False
# Epoch : 228 || Train Loss: 7.43239 // 0.69086 || Test Loss: 13.86814 // 0.6909 || Warmup : False
# Epoch : 229 || Train Loss: 5.59063 // 0.69157 || Test Loss: 28.11788 // 0.6909 || Warmup : False
# Epoch : 230 || Train Loss: 6.85847 // 0.69138 || Test Loss: 19.75287 // 0.6878 || Warmup : False
# Epoch : 231 || Train Loss: 7.02593 // 0.6914 || Test Loss: 25.98543 // 0.69051 || Warmup : False
# Epoch : 232 || Train Loss: 7.77432 // 0.69172 || Test Loss: 14.75548 // 0.68908 || Warmup : False
# Epoch : 233 || Train Loss: 7.52083 // 0.6916 || Test Loss: 17.64981 // 0.68978 || Warmup : False
# Epoch : 234 || Train Loss: 5.81776 // 0.69147 || Test Loss: 21.373 // 0.68897 || Warmup : False
# Epoch : 235 || Train Loss: 8.42246 // 0.69157 || Test Loss: 17.46721 // 0.68648 || Warmup : False
# Epoch : 236 || Train Loss: 7.25431 // 0.69243 || Test Loss: 16.02408 // 0.68654 || Warmup : False
# Epoch : 237 || Train Loss: 7.37388 // 0.6919 || Test Loss: 25.51554 // 0.68809 || Warmup : False
# Epoch : 238 || Train Loss: 6.50624 // 0.69193 || Test Loss: 24.75319 // 0.68755 || Warmup : False
# Epoch : 239 || Train Loss: 6.7819 // 0.69139 || Test Loss: 9.18761 // 0.68987 || Warmup : False
# Epoch : 240 || Train Loss: 7.85536 // 0.6922 || Test Loss: 15.71194 // 0.68497 || Warmup : False
# Epoch : 241 || Train Loss: 6.54812 // 0.69219 || Test Loss: 20.64636 // 0.68856 || Warmup : False
# Epoch : 242 || Train Loss: 7.02877 // 0.69178 || Test Loss: 18.02575 // 0.68881 || Warmup : False
# Epoch : 243 || Train Loss: 6.45927 // 0.69235 || Test Loss: 13.7814 // 0.68924 || Warmup : False
# Epoch : 244 || Train Loss: 6.76681 // 0.69202 || Test Loss: 11.43518 // 0.69641 || Warmup : False
# Epoch : 245 || Train Loss: 6.71628 // 0.6914 || Test Loss: 9.34087 // 0.69142 || Warmup : False
# Epoch : 246 || Train Loss: 5.90079 // 0.69177 || Test Loss: 12.71824 // 0.68675 || Warmup : False
# Epoch : 247 || Train Loss: 6.30016 // 0.69144 || Test Loss: 16.52849 // 0.68644 || Warmup : False
# Epoch : 248 || Train Loss: 5.44403 // 0.69136 || Test Loss: 24.69892 // 0.69531 || Warmup : False
# Epoch : 249 || Train Loss: 7.20928 // 0.69139 || Test Loss: 13.38523 // 0.69467 || Warmup : False
# Epoch : 250 || Train Loss: 5.83352 // 0.69121 || Test Loss: 16.75592 // 0.6939 || Warmup : False
# Epoch : 251 || Train Loss: 7.04308 // 0.69199 || Test Loss: 11.24798 // 0.69151 || Warmup : False
# Epoch : 252 || Train Loss: 6.88744 // 0.69158 || Test Loss: 19.71087 // 0.6918 || Warmup : False
# Epoch : 253 || Train Loss: 5.51294 // 0.69176 || Test Loss: 16.25883 // 0.69212 || Warmup : False
# Epoch : 254 || Train Loss: 6.75158 // 0.69212 || Test Loss: 22.17336 // 0.68721 || Warmup : False
# Epoch : 255 || Train Loss: 6.24827 // 0.6913 || Test Loss: 20.62927 // 0.68837 || Warmup : False
# Epoch : 256 || Train Loss: 6.29053 // 0.69166 || Test Loss: 11.54053 // 0.69287 || Warmup : False
# Epoch : 257 || Train Loss: 5.98148 // 0.69139 || Test Loss: 20.90641 // 0.68879 || Warmup : False
# Epoch : 258 || Train Loss: 5.75062 // 0.69144 || Test Loss: 24.63891 // 0.69645 || Warmup : False
# Epoch : 259 || Train Loss: 7.37531 // 0.69192 || Test Loss: 23.78092 // 0.69568 || Warmup : False
# Epoch : 260 || Train Loss: 6.46713 // 0.69112 || Test Loss: 19.47659 // 0.68922 || Warmup : False
# Epoch : 261 || Train Loss: 6.37588 // 0.69148 || Test Loss: 34.53372 // 0.69413 || Warmup : False
# Epoch : 262 || Train Loss: 6.73971 // 0.69155 || Test Loss: 20.67179 // 0.6888 || Warmup : False
# Epoch : 263 || Train Loss: 4.8005 // 0.69125 || Test Loss: 17.56216 // 0.69563 || Warmup : False
# Epoch : 264 || Train Loss: 6.78663 // 0.6917 || Test Loss: 18.08997 // 0.69352 || Warmup : False
# Epoch : 265 || Train Loss: 7.77275 // 0.69168 || Test Loss: 22.6759 // 0.6813 || Warmup : False
# Epoch : 266 || Train Loss: 9.55901 // 0.69132 || Test Loss: 41.80388 // 0.69283 || Warmup : False
# Epoch : 267 || Train Loss: 7.416 // 0.6919 || Test Loss: 12.92515 // 0.69503 || Warmup : False
# Epoch : 268 || Train Loss: 6.18935 // 0.69165 || Test Loss: 15.58646 // 0.68862 || Warmup : False
# Epoch : 269 || Train Loss: 5.22527 // 0.6917 || Test Loss: 17.39654 // 0.69645 || Warmup : False
# Epoch : 270 || Train Loss: 5.75038 // 0.69151 || Test Loss: 18.12055 // 0.68832 || Warmup : False
# Epoch : 271 || Train Loss: 4.88382 // 0.6914 || Test Loss: 18.37806 // 0.69327 || Warmup : False
# Epoch : 272 || Train Loss: 10.18116 // 0.69124 || Test Loss: 24.35643 // 0.69291 || Warmup : False
# Epoch : 273 || Train Loss: 6.77408 // 0.6917 || Test Loss: 25.18235 // 0.6841 || Warmup : False
# Epoch : 274 || Train Loss: 4.76197 // 0.69155 || Test Loss: 11.04153 // 0.68282 || Warmup : False
# Epoch : 275 || Train Loss: 6.82957 // 0.69183 || Test Loss: 10.77008 // 0.68885 || Warmup : False
# Epoch : 276 || Train Loss: 7.08556 // 0.6911 || Test Loss: 29.37489 // 0.69418 || Warmup : False
# Epoch : 277 || Train Loss: 6.93274 // 0.69124 || Test Loss: 17.04827 // 0.69533 || Warmup : False
# Epoch : 278 || Train Loss: 5.57982 // 0.69156 || Test Loss: 23.64324 // 0.68463 || Warmup : False
# Epoch : 279 || Train Loss: 5.52281 // 0.69134 || Test Loss: 17.27057 // 0.68618 || Warmup : False
# Epoch : 280 || Train Loss: 4.70333 // 0.69139 || Test Loss: 16.021 // 0.69614 || Warmup : False
# Epoch : 281 || Train Loss: 5.77721 // 0.69175 || Test Loss: 19.3333 // 0.69089 || Warmup : False
# Epoch : 282 || Train Loss: 5.95576 // 0.69167 || Test Loss: 16.95637 // 0.69169 || Warmup : False
# Epoch : 283 || Train Loss: 7.01241 // 0.69152 || Test Loss: 20.14948 // 0.68947 || Warmup : False
# Epoch : 284 || Train Loss: 4.88963 // 0.69148 || Test Loss: 14.24848 // 0.68452 || Warmup : False
# Epoch : 285 || Train Loss: 7.44002 // 0.69169 || Test Loss: 36.48546 // 0.69104 || Warmup : False
# Epoch : 286 || Train Loss: 4.85257 // 0.69136 || Test Loss: 17.96721 // 0.69193 || Warmup : False
# Epoch : 287 || Train Loss: 3.69865 // 0.69157 || Test Loss: 40.10258 // 0.68854 || Warmup : False
# Epoch : 288 || Train Loss: 5.57638 // 0.69095 || Test Loss: 11.94106 // 0.69235 || Warmup : False
# Epoch : 289 || Train Loss: 4.26737 // 0.69148 || Test Loss: 11.40085 // 0.68947 || Warmup : False
# Epoch : 290 || Train Loss: 5.4874 // 0.69129 || Test Loss: 21.78828 // 0.68784 || Warmup : False
# Epoch : 291 || Train Loss: 4.373 // 0.69177 || Test Loss: 17.29535 // 0.69097 || Warmup : False
# Epoch : 292 || Train Loss: 4.86431 // 0.69131 || Test Loss: 35.45713 // 0.6876 || Warmup : False
# Epoch : 293 || Train Loss: 5.44743 // 0.69084 || Test Loss: 9.00695 // 0.69161 || Warmup : False
# Epoch : 294 || Train Loss: 5.73255 // 0.69162 || Test Loss: 15.05827 // 0.69063 || Warmup : False
# Epoch : 295 || Train Loss: 4.80208 // 0.69106 || Test Loss: 21.00341 // 0.68556 || Warmup : False
# Epoch : 296 || Train Loss: 6.78307 // 0.69131 || Test Loss: 20.51884 // 0.68681 || Warmup : False
# Epoch : 297 || Train Loss: 5.46409 // 0.69121 || Test Loss: 15.85928 // 0.68803 || Warmup : False
# Epoch : 298 || Train Loss: 4.85176 // 0.69154 || Test Loss: 14.76411 // 0.69458 || Warmup : False
# Epoch : 299 || Train Loss: 5.13746 // 0.69143 || Test Loss: 16.34084 // 0.6888 || Warmup : False

# %%
patches = patches.cpu()
patches.eval()
predictive = pyro.infer.Predictive(patches.generate, num_samples=1)

# %% [markdown]
# ## Reconstruction

# %%
rec = predictive(dataset[:][0], dataset[:][1], dataset[:][2])['x']
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')
scatter = ax.scatter(rec[:][0][:,0], rec[:][0][:,1] ,rec[:][0][:,2], c=ys.argmax(-1), cmap="Set2")
ax.grid(False)

ax.set_xlabel('X', weight='bold', labelpad=30, fontsize=18)
ax.set_ylabel('Y', weight='bold', labelpad=30, fontsize=18)
ax.set_zlabel('Z', weight='bold', labelpad=7, fontsize=18)

sns.set(font_scale=1)


ax.set_facecolor('white')


fig.savefig("swiss_roll_reconstructed_ld.png", dpi=300, bbox_inches="tight")





plt.show()

# %% [markdown]
# ## Latent Components

# %%
sns.set(font_scale=3)

# %%
loc, _ = patches.get_weights()
fig, ax = plt.subplots(2,1,figsize=(15,15))

cmap = sns.blend_palette([(0.2, 0.2, 0.2), (0.125, 0.771, 0.561)], as_cmap=True, n_colors=20)

heatmap_common = sns.heatmap(loc[:2], ax=ax[0], cbar=True, xticklabels = ["X", "Y", "Z"], yticklabels=["Z1", "Z2"], cmap=cmap)
heatmap_spec = sns.heatmap(loc[2:], ax=ax[1], cbar=True, xticklabels = ["X", "Y", "Z"], yticklabels=["W1", "W2"], cmap=cmap)

#plt.savefig("linear_latents.png", dpi=300, bbox_inches="tight")

# %%
rho_latent = patches.rho_l_encoder(dataset[:][0])[0]

rho_y = _broadcast_inputs([rho_latent, dataset[:][1]])
rho_y = torch.cat(rho_y, dim=-1)


w_latent = patches.w_encoder(rho_y)[0]
z_latent = patches.z_encoder(rho_latent)[0]

# %%
sns.set(font_scale=1)

# %%
ax_order = [["Z1", "Z2"], ["Z2",  "W1"], ["W1", "W2"], ["W2", "Z1"]]
lat_match = {
    "Z1" : z_latent[:,0].detach(),
    "Z2" : z_latent[:,1].detach(),
    "W1" : w_latent[:,0].detach(),
    "W2" : w_latent[:,1].detach(),
}
fig,ax = plt.subplots(2, 2, figsize=(15,15))


for i in range(len(ax_order)):
    cur_ax = ax[i//2][i%2]
    x_n, y_n = ax_order[i][0], ax_order[i][1]
    x, y = lat_match[x_n], lat_match[y_n]
    
    cur_ax.scatter(x, y, c=ys.argmax(-1), alpha=0.5, cmap="Set2")
    cur_ax.set_xlabel(x_n, fontsize=28)
    cur_ax.set_ylabel(y_n, fontsize=28)
    cur_ax.set_xticklabels([])
    cur_ax.set_yticklabels([])
    cur_ax.set_xticks([])
    cur_ax.set_yticks([])
    cur_ax.set_facecolor('white')
    
    
    for spine in cur_ax.spines.values():
            spine.set_edgecolor('black')


plt.show()

# %%
# Uncomment to generate figures 

"""
for i in range(len(ax_order)):
    fig, ax = plt.subplots(1,1,figsize=(15,15))
    x_n, y_n = ax_order[i][0], ax_order[i][1]
    x, y = lat_match[x_n], lat_match[y_n]
    
    ax.scatter(x, y, c=ys.argmax(-1), alpha=0.5, cmap="Set2")
    ax.set_xlabel(x_n, fontsize=28)
    ax.set_ylabel(y_n, fontsize=28)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_facecolor('white')
    
    
    for spine in ax.spines.values():
            spine.set_edgecolor('black')

    fig.savefig(f"{x_n}_{y_n}.png", dpi=300, bbox_inches="tight")
    plt.close(fig)
"""
pass
